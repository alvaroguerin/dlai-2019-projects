# %% [markdown]
# # **Exercise 2. Autoencoder**

# %% [markdown]
# Second exercise for the Project of DLAI Fall semester 2019/2020.
#
# Authors:
# * Carlos Alejandro López Molina
# * María González i Calabuig
# * Roser Batlle Roca
# * Jordi Biosca Caro

# %% [markdown]
# Import of different libraries used to build the script:

# %%
import torch

import numpy as np
import torchvision as tv
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import matplotlib
import matplotlib.pyplot as plt
from torch.autograd import Variable
from torchvision.utils import save_image
from torchvision import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.utils.data.sampler import SubsetRandomSampler
from tabulate import tabulate
from torch.utils import data 

seed = 1
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# Definition of hyper-parameters:

# %%
hparams = {
    'batch_size': 64,
    'num_epochs': 5,
    'test_batch_size': 64,
    'hidden_size': 64,
    'hidden_size_2': 128,
    'hidden_size_3': 64,
    'num_classes': 10,
    'num_inputs': 1, 
    'learning_rate': 1e-3,
    'log_interval': 100,
    'num_workers': 4,
    'kernel_size': 3,
    'encoder_key': [1, 5, 25, 50, 100],
    'subset_size': 100
}

hparams['device'] = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# **STEP 1** - Select 100 images from MNIST dataset

# %%
mnist_trainset = datasets.MNIST('data', train=True, download=True,
                                transform=transforms.Compose([
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.1307,), (0.3081,))
                                ]))
mnist_testset = datasets.MNIST('data', train=False, 
                               transform=transforms.Compose([
                                   transforms.ToTensor(),
                                   transforms.Normalize((0.1307,), (0.3081,))
                               ]))


train_loader = torch.utils.data.DataLoader(mnist_trainset, 
                                           hparams['batch_size'], 
                                           shuffle=False,
                                           num_workers=hparams['num_workers'], 
                                           )

test_loader = torch.utils.data.DataLoader(mnist_trainset, 
                                          hparams['batch_size'], 
                                          shuffle=False,
                                          num_workers=hparams['num_workers'], 
                                          )

samples_train = torch.utils.data.Subset(train_loader, 100)
samples_test = torch.utils.data.Subset(test_loader, 100)

# %% [markdown]
# **STEP 2** - Reusing the Encoder of the Autoencoder from Ex1.
# Bottleneck size = 100.

# %%
class ConvAutoEncoder(nn.Module):

  def __init__(self):
    super(ConvAutoEncoder,self).__init__()

    self.encoder = nn.Sequential(
        nn.Conv2d(hparams['num_inputs'], hparams['hidden_size'], 4, padding=3, stride=2), # surten 16,16
        nn.ReLU(True),
        nn.Conv2d(hparams['hidden_size'], hparams['hidden_size_2'], 4, padding=1, stride=2), #surten 8,8
        nn.ReLU(True),
        nn.Conv2d(hparams['hidden_size_2'], 25, 4, stride=2), #surten 3,3
        nn.ReLU(True),
        nn.MaxPool2d(2, stride=1) # surten 2,2
    )

    self.decoder = nn.Sequential(
        nn.ConvTranspose2d(25, hparams['hidden_size_2'], 3, stride=2), #surten 5,5
        nn.ReLU(True),
        nn.ConvTranspose2d(hparams['hidden_size_2'], hparams['hidden_size'], 5, stride=3, padding=1), # surten 15,15
        nn.ReLU(True),
        nn.ConvTranspose2d(hparams['hidden_size'], hparams['num_inputs'], 2, stride=2, padding=1), #surten 28,28
        nn.Tanh(),
    )

  def forward(self,x):
    x = self.encoder(x)
    x = self.decoder(x)
    return x

# %%
losses_train = []
losses_test = []
model = ConvAutoEncoder()
model = model.to(hparams['device'])
distance = nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=hparams['learning_rate'], weight_decay=1e-5)
for epoch in range (hparams['num_epochs']):
  for batch_id, data in enumerate(train_loader):
    img, _ = data
    img = img.to(hparams['device'])
    # Forward pass
    output = model(img)
    loss = distance(output, img)
    losses_train.append(loss.cpu().data.item())
    # Backward pass
    optimizer.zero_grad() 
    loss.backward()
    optimizer.step()
    # Log message
    print('TRAIN: epoch[{}/{}], loss:{:.4f}'.format(epoch+1, hparams['num_epochs'], loss.item()))
  for data in test_loader:
    img, _ = data
    img = img.to(hparams['device'])
    # Forward pass
    output = model(img)
    loss = distance(output, img)
    losses_test.append(loss.cpu().data.item())
    # Backward pass
    optimizer.zero_grad() 
    loss.backward()
    optimizer.step()
   # Log message
    print('TEST: epoch[{}/{}], loss:{:.4f}'.format(epoch+1, hparams['num_epochs'], loss.item()))
# Out:
# TRAIN: epoch[1/5], loss:0.3309
# TRAIN: epoch[1/5], loss:0.3301
# TRAIN: epoch[1/5], loss:0.3134
# TRAIN: epoch[1/5], loss:0.3287
# TRAIN: epoch[1/5], loss:0.2917
# TRAIN: epoch[1/5], loss:0.2915
# TRAIN: epoch[1/5], loss:0.2766
# TRAIN: epoch[1/5], loss:0.2789
# TRAIN: epoch[1/5], loss:0.2800
# TRAIN: epoch[1/5], loss:0.2598
# TRAIN: epoch[1/5], loss:0.2777
# TRAIN: epoch[1/5], loss:0.2968
# TRAIN: epoch[1/5], loss:0.2779
# TRAIN: epoch[1/5], loss:0.2842
# TRAIN: epoch[1/5], loss:0.2733
# TRAIN: epoch[1/5], loss:0.2606
# TRAIN: epoch[1/5], loss:0.2388
# TRAIN: epoch[1/5], loss:0.2442
# TRAIN: epoch[1/5], loss:0.2764
# TRAIN: epoch[1/5], loss:0.2994
# TRAIN: epoch[1/5], loss:0.2860
# TRAIN: epoch[1/5], loss:0.3031
# TRAIN: epoch[1/5], loss:0.2637
# TRAIN: epoch[1/5], loss:0.2513
# TRAIN: epoch[1/5], loss:0.2508
# TRAIN: epoch[1/5], loss:0.2474
# TRAIN: epoch[1/5], loss:0.2421
# TRAIN: epoch[1/5], loss:0.2489
# TRAIN: epoch[1/5], loss:0.2416
# TRAIN: epoch[1/5], loss:0.2561
# TRAIN: epoch[1/5], loss:0.2635
# TRAIN: epoch[1/5], loss:0.2654
# TRAIN: epoch[1/5], loss:0.2576
# TRAIN: epoch[1/5], loss:0.2474
# TRAIN: epoch[1/5], loss:0.2391
# TRAIN: epoch[1/5], loss:0.2585
# TRAIN: epoch[1/5], loss:0.2393
# TRAIN: epoch[1/5], loss:0.2338
# TRAIN: epoch[1/5], loss:0.2301
# TRAIN: epoch[1/5], loss:0.2441
# TRAIN: epoch[1/5], loss:0.2347
# TRAIN: epoch[1/5], loss:0.2461
# TRAIN: epoch[1/5], loss:0.2304
# TRAIN: epoch[1/5], loss:0.2349
# TRAIN: epoch[1/5], loss:0.2394
# TRAIN: epoch[1/5], loss:0.2305
# TRAIN: epoch[1/5], loss:0.2024
# TRAIN: epoch[1/5], loss:0.2225
# TRAIN: epoch[1/5], loss:0.2005
# TRAIN: epoch[1/5], loss:0.2004
# TRAIN: epoch[1/5], loss:0.2008
# TRAIN: epoch[1/5], loss:0.1923
# TRAIN: epoch[1/5], loss:0.2181
# TRAIN: epoch[1/5], loss:0.1941
# TRAIN: epoch[1/5], loss:0.1903
# TRAIN: epoch[1/5], loss:0.2151
# TRAIN: epoch[1/5], loss:0.2290
# TRAIN: epoch[1/5], loss:0.2383
# TRAIN: epoch[1/5], loss:0.2110
# TRAIN: epoch[1/5], loss:0.2023
# TRAIN: epoch[1/5], loss:0.1948
# TRAIN: epoch[1/5], loss:0.1997
# TRAIN: epoch[1/5], loss:0.1946
# TRAIN: epoch[1/5], loss:0.2104
# TRAIN: epoch[1/5], loss:0.1947
# TRAIN: epoch[1/5], loss:0.1881
# TRAIN: epoch[1/5], loss:0.2053
# TRAIN: epoch[1/5], loss:0.1900
# TRAIN: epoch[1/5], loss:0.1807
# TRAIN: epoch[1/5], loss:0.1948
# TRAIN: epoch[1/5], loss:0.2199
# TRAIN: epoch[1/5], loss:0.1947
# TRAIN: epoch[1/5], loss:0.2120
# TRAIN: epoch[1/5], loss:0.2271
# TRAIN: epoch[1/5], loss:0.2107
# TRAIN: epoch[1/5], loss:0.2191
# TRAIN: epoch[1/5], loss:0.2088
# TRAIN: epoch[1/5], loss:0.1754
# TRAIN: epoch[1/5], loss:0.1902
# TRAIN: epoch[1/5], loss:0.2013
# TRAIN: epoch[1/5], loss:0.1991
# TRAIN: epoch[1/5], loss:0.1944
# TRAIN: epoch[1/5], loss:0.1892
# TRAIN: epoch[1/5], loss:0.2125
# TRAIN: epoch[1/5], loss:0.2107
# TRAIN: epoch[1/5], loss:0.2024
# TRAIN: epoch[1/5], loss:0.1951
# TRAIN: epoch[1/5], loss:0.1898
# TRAIN: epoch[1/5], loss:0.1900
# TRAIN: epoch[1/5], loss:0.1909
# TRAIN: epoch[1/5], loss:0.1785
# TRAIN: epoch[1/5], loss:0.1725
# TRAIN: epoch[1/5], loss:0.1791
# TRAIN: epoch[1/5], loss:0.2170
# TRAIN: epoch[1/5], loss:0.2149
# TRAIN: epoch[1/5], loss:0.2131
# TRAIN: epoch[1/5], loss:0.2080
# TRAIN: epoch[1/5], loss:0.1906
# TRAIN: epoch[1/5], loss:0.1946
# TRAIN: epoch[1/5], loss:0.1898
# TRAIN: epoch[1/5], loss:0.1870
# TRAIN: epoch[1/5], loss:0.1790
# TRAIN: epoch[1/5], loss:0.1607
# TRAIN: epoch[1/5], loss:0.1818
# TRAIN: epoch[1/5], loss:0.1463
# TRAIN: epoch[1/5], loss:0.1532
# TRAIN: epoch[1/5], loss:0.1440
# TRAIN: epoch[1/5], loss:0.1865
# TRAIN: epoch[1/5], loss:0.1922
# TRAIN: epoch[1/5], loss:0.1745
# TRAIN: epoch[1/5], loss:0.1600
# TRAIN: epoch[1/5], loss:0.1588
# TRAIN: epoch[1/5], loss:0.1564
# TRAIN: epoch[1/5], loss:0.1632
# TRAIN: epoch[1/5], loss:0.1377
# TRAIN: epoch[1/5], loss:0.1507
# TRAIN: epoch[1/5], loss:0.1611
# TRAIN: epoch[1/5], loss:0.1519
# TRAIN: epoch[1/5], loss:0.1567
# TRAIN: epoch[1/5], loss:0.1738
# TRAIN: epoch[1/5], loss:0.1645
# TRAIN: epoch[1/5], loss:0.1720
# TRAIN: epoch[1/5], loss:0.1816
# TRAIN: epoch[1/5], loss:0.1998
# TRAIN: epoch[1/5], loss:0.1893
# TRAIN: epoch[1/5], loss:0.1924
# TRAIN: epoch[1/5], loss:0.1776
# TRAIN: epoch[1/5], loss:0.1488
# TRAIN: epoch[1/5], loss:0.1579
# TRAIN: epoch[1/5], loss:0.1813
# TRAIN: epoch[1/5], loss:0.1729
# TRAIN: epoch[1/5], loss:0.1668
# TRAIN: epoch[1/5], loss:0.2170
# TRAIN: epoch[1/5], loss:0.1991
# TRAIN: epoch[1/5], loss:0.1960
# TRAIN: epoch[1/5], loss:0.2040
# TRAIN: epoch[1/5], loss:0.1789
# TRAIN: epoch[1/5], loss:0.1678
# TRAIN: epoch[1/5], loss:0.1622
# TRAIN: epoch[1/5], loss:0.1750
# TRAIN: epoch[1/5], loss:0.1614
# TRAIN: epoch[1/5], loss:0.1665
# TRAIN: epoch[1/5], loss:0.1478
# TRAIN: epoch[1/5], loss:0.1630
# TRAIN: epoch[1/5], loss:0.1384
# TRAIN: epoch[1/5], loss:0.1724
# TRAIN: epoch[1/5], loss:0.1795
# TRAIN: epoch[1/5], loss:0.1769
# TRAIN: epoch[1/5], loss:0.1913
# TRAIN: epoch[1/5], loss:0.1547
# TRAIN: epoch[1/5], loss:0.1668
# TRAIN: epoch[1/5], loss:0.1799
# TRAIN: epoch[1/5], loss:0.1721
# TRAIN: epoch[1/5], loss:0.1615
# TRAIN: epoch[1/5], loss:0.1626
# TRAIN: epoch[1/5], loss:0.1579
# TRAIN: epoch[1/5], loss:0.1798
# TRAIN: epoch[1/5], loss:0.1568
# TRAIN: epoch[1/5], loss:0.1455
# TRAIN: epoch[1/5], loss:0.2159
# TRAIN: epoch[1/5], loss:0.2203
# TRAIN: epoch[1/5], loss:0.1896
# TRAIN: epoch[1/5], loss:0.1783
# TRAIN: epoch[1/5], loss:0.1897
# TRAIN: epoch[1/5], loss:0.1763
# TRAIN: epoch[1/5], loss:0.1642
# TRAIN: epoch[1/5], loss:0.1490
# TRAIN: epoch[1/5], loss:0.1604
# TRAIN: epoch[1/5], loss:0.1711
# TRAIN: epoch[1/5], loss:0.1675
# TRAIN: epoch[1/5], loss:0.1675
# TRAIN: epoch[1/5], loss:0.1800
# TRAIN: epoch[1/5], loss:0.1832
# TRAIN: epoch[1/5], loss:0.1640
# TRAIN: epoch[1/5], loss:0.1656
# TRAIN: epoch[1/5], loss:0.1603
# TRAIN: epoch[1/5], loss:0.1551
# TRAIN: epoch[1/5], loss:0.1625
# TRAIN: epoch[1/5], loss:0.1603
# TRAIN: epoch[1/5], loss:0.1598
# TRAIN: epoch[1/5], loss:0.1564
# TRAIN: epoch[1/5], loss:0.1602
# TRAIN: epoch[1/5], loss:0.1633
# TRAIN: epoch[1/5], loss:0.1570
# TRAIN: epoch[1/5], loss:0.1599
# TRAIN: epoch[1/5], loss:0.1570
# TRAIN: epoch[1/5], loss:0.1516
# TRAIN: epoch[1/5], loss:0.1827
# TRAIN: epoch[1/5], loss:0.1684
# TRAIN: epoch[1/5], loss:0.1654
# TRAIN: epoch[1/5], loss:0.1722
# TRAIN: epoch[1/5], loss:0.1767
# TRAIN: epoch[1/5], loss:0.1688
# TRAIN: epoch[1/5], loss:0.1700
# TRAIN: epoch[1/5], loss:0.1765
# TRAIN: epoch[1/5], loss:0.1702
# TRAIN: epoch[1/5], loss:0.1721
# TRAIN: epoch[1/5], loss:0.1756
# TRAIN: epoch[1/5], loss:0.1668
# TRAIN: epoch[1/5], loss:0.1533
# TRAIN: epoch[1/5], loss:0.1401
# TRAIN: epoch[1/5], loss:0.1664
# TRAIN: epoch[1/5], loss:0.1885
# TRAIN: epoch[1/5], loss:0.1836
# TRAIN: epoch[1/5], loss:0.2003
# TRAIN: epoch[1/5], loss:0.1713
# TRAIN: epoch[1/5], loss:0.1749
# TRAIN: epoch[1/5], loss:0.1709
# TRAIN: epoch[1/5], loss:0.1721
# TRAIN: epoch[1/5], loss:0.1638
# TRAIN: epoch[1/5], loss:0.1732
# TRAIN: epoch[1/5], loss:0.1876
# TRAIN: epoch[1/5], loss:0.1709
# TRAIN: epoch[1/5], loss:0.1485
# TRAIN: epoch[1/5], loss:0.1346
# TRAIN: epoch[1/5], loss:0.1468
# TRAIN: epoch[1/5], loss:0.1557
# TRAIN: epoch[1/5], loss:0.1588
# TRAIN: epoch[1/5], loss:0.1480
# TRAIN: epoch[1/5], loss:0.1870
# TRAIN: epoch[1/5], loss:0.1853
# TRAIN: epoch[1/5], loss:0.1899
# TRAIN: epoch[1/5], loss:0.1786
# TRAIN: epoch[1/5], loss:0.1781
# TRAIN: epoch[1/5], loss:0.1710
# TRAIN: epoch[1/5], loss:0.1538
# TRAIN: epoch[1/5], loss:0.1473
# TRAIN: epoch[1/5], loss:0.1450
# TRAIN: epoch[1/5], loss:0.1578
# TRAIN: epoch[1/5], loss:0.1711
# TRAIN: epoch[1/5], loss:0.1589
# TRAIN: epoch[1/5], loss:0.1639
# TRAIN: epoch[1/5], loss:0.1562
# TRAIN: epoch[1/5], loss:0.1538
# TRAIN: epoch[1/5], loss:0.1413
# TRAIN: epoch[1/5], loss:0.1561
# TRAIN: epoch[1/5], loss:0.1478
# TRAIN: epoch[1/5], loss:0.1413
# TRAIN: epoch[1/5], loss:0.1499
# TRAIN: epoch[1/5], loss:0.1404
# TRAIN: epoch[1/5], loss:0.1389
# TRAIN: epoch[1/5], loss:0.1416
# TRAIN: epoch[1/5], loss:0.1525
# TRAIN: epoch[1/5], loss:0.1469
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1530
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1481
# TRAIN: epoch[1/5], loss:0.1654
# TRAIN: epoch[1/5], loss:0.1491
# TRAIN: epoch[1/5], loss:0.1620
# TRAIN: epoch[1/5], loss:0.1730
# TRAIN: epoch[1/5], loss:0.1686
# TRAIN: epoch[1/5], loss:0.1620
# TRAIN: epoch[1/5], loss:0.1536
# TRAIN: epoch[1/5], loss:0.1564
# TRAIN: epoch[1/5], loss:0.1486
# TRAIN: epoch[1/5], loss:0.1496
# TRAIN: epoch[1/5], loss:0.1532
# TRAIN: epoch[1/5], loss:0.1451
# TRAIN: epoch[1/5], loss:0.1445
# TRAIN: epoch[1/5], loss:0.1509
# TRAIN: epoch[1/5], loss:0.1541
# TRAIN: epoch[1/5], loss:0.1446
# TRAIN: epoch[1/5], loss:0.1474
# TRAIN: epoch[1/5], loss:0.1542
# TRAIN: epoch[1/5], loss:0.1459
# TRAIN: epoch[1/5], loss:0.1653
# TRAIN: epoch[1/5], loss:0.1698
# TRAIN: epoch[1/5], loss:0.1609
# TRAIN: epoch[1/5], loss:0.1770
# TRAIN: epoch[1/5], loss:0.1449
# TRAIN: epoch[1/5], loss:0.1460
# TRAIN: epoch[1/5], loss:0.1525
# TRAIN: epoch[1/5], loss:0.1423
# TRAIN: epoch[1/5], loss:0.1418
# TRAIN: epoch[1/5], loss:0.1396
# TRAIN: epoch[1/5], loss:0.1400
# TRAIN: epoch[1/5], loss:0.1358
# TRAIN: epoch[1/5], loss:0.1352
# TRAIN: epoch[1/5], loss:0.1550
# TRAIN: epoch[1/5], loss:0.1483
# TRAIN: epoch[1/5], loss:0.1451
# TRAIN: epoch[1/5], loss:0.1544
# TRAIN: epoch[1/5], loss:0.1578
# TRAIN: epoch[1/5], loss:0.1486
# TRAIN: epoch[1/5], loss:0.1366
# TRAIN: epoch[1/5], loss:0.1510
# TRAIN: epoch[1/5], loss:0.1415
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1531
# TRAIN: epoch[1/5], loss:0.1569
# TRAIN: epoch[1/5], loss:0.1480
# TRAIN: epoch[1/5], loss:0.1464
# TRAIN: epoch[1/5], loss:0.1451
# TRAIN: epoch[1/5], loss:0.1525
# TRAIN: epoch[1/5], loss:0.1448
# TRAIN: epoch[1/5], loss:0.1334
# TRAIN: epoch[1/5], loss:0.1400
# TRAIN: epoch[1/5], loss:0.1405
# TRAIN: epoch[1/5], loss:0.1866
# TRAIN: epoch[1/5], loss:0.1602
# TRAIN: epoch[1/5], loss:0.1807
# TRAIN: epoch[1/5], loss:0.1728
# TRAIN: epoch[1/5], loss:0.1731
# TRAIN: epoch[1/5], loss:0.1793
# TRAIN: epoch[1/5], loss:0.1698
# TRAIN: epoch[1/5], loss:0.1689
# TRAIN: epoch[1/5], loss:0.1723
# TRAIN: epoch[1/5], loss:0.1716
# TRAIN: epoch[1/5], loss:0.1608
# TRAIN: epoch[1/5], loss:0.1799
# TRAIN: epoch[1/5], loss:0.1713
# TRAIN: epoch[1/5], loss:0.1563
# TRAIN: epoch[1/5], loss:0.1627
# TRAIN: epoch[1/5], loss:0.1558
# TRAIN: epoch[1/5], loss:0.1500
# TRAIN: epoch[1/5], loss:0.1430
# TRAIN: epoch[1/5], loss:0.1602
# TRAIN: epoch[1/5], loss:0.1434
# TRAIN: epoch[1/5], loss:0.1621
# TRAIN: epoch[1/5], loss:0.1533
# TRAIN: epoch[1/5], loss:0.1677
# TRAIN: epoch[1/5], loss:0.1587
# TRAIN: epoch[1/5], loss:0.1446
# TRAIN: epoch[1/5], loss:0.1566
# TRAIN: epoch[1/5], loss:0.1499
# TRAIN: epoch[1/5], loss:0.1688
# TRAIN: epoch[1/5], loss:0.1497
# TRAIN: epoch[1/5], loss:0.1310
# TRAIN: epoch[1/5], loss:0.1464
# TRAIN: epoch[1/5], loss:0.1494
# TRAIN: epoch[1/5], loss:0.1593
# TRAIN: epoch[1/5], loss:0.1509
# TRAIN: epoch[1/5], loss:0.1593
# TRAIN: epoch[1/5], loss:0.1594
# TRAIN: epoch[1/5], loss:0.1673
# TRAIN: epoch[1/5], loss:0.1245
# TRAIN: epoch[1/5], loss:0.1392
# TRAIN: epoch[1/5], loss:0.1220
# TRAIN: epoch[1/5], loss:0.1866
# TRAIN: epoch[1/5], loss:0.1776
# TRAIN: epoch[1/5], loss:0.1830
# TRAIN: epoch[1/5], loss:0.1750
# TRAIN: epoch[1/5], loss:0.1580
# TRAIN: epoch[1/5], loss:0.1506
# TRAIN: epoch[1/5], loss:0.1532
# TRAIN: epoch[1/5], loss:0.1524
# TRAIN: epoch[1/5], loss:0.1431
# TRAIN: epoch[1/5], loss:0.1519
# TRAIN: epoch[1/5], loss:0.1494
# TRAIN: epoch[1/5], loss:0.1483
# TRAIN: epoch[1/5], loss:0.1586
# TRAIN: epoch[1/5], loss:0.1639
# TRAIN: epoch[1/5], loss:0.1873
# TRAIN: epoch[1/5], loss:0.1808
# TRAIN: epoch[1/5], loss:0.1634
# TRAIN: epoch[1/5], loss:0.1691
# TRAIN: epoch[1/5], loss:0.1747
# TRAIN: epoch[1/5], loss:0.1689
# TRAIN: epoch[1/5], loss:0.1826
# TRAIN: epoch[1/5], loss:0.1660
# TRAIN: epoch[1/5], loss:0.1546
# TRAIN: epoch[1/5], loss:0.1579
# TRAIN: epoch[1/5], loss:0.1615
# TRAIN: epoch[1/5], loss:0.1596
# TRAIN: epoch[1/5], loss:0.1519
# TRAIN: epoch[1/5], loss:0.1454
# TRAIN: epoch[1/5], loss:0.1426
# TRAIN: epoch[1/5], loss:0.1321
# TRAIN: epoch[1/5], loss:0.1363
# TRAIN: epoch[1/5], loss:0.1584
# TRAIN: epoch[1/5], loss:0.1565
# TRAIN: epoch[1/5], loss:0.1495
# TRAIN: epoch[1/5], loss:0.1514
# TRAIN: epoch[1/5], loss:0.1578
# TRAIN: epoch[1/5], loss:0.1550
# TRAIN: epoch[1/5], loss:0.1468
# TRAIN: epoch[1/5], loss:0.1477
# TRAIN: epoch[1/5], loss:0.1503
# TRAIN: epoch[1/5], loss:0.1361
# TRAIN: epoch[1/5], loss:0.1649
# TRAIN: epoch[1/5], loss:0.1594
# TRAIN: epoch[1/5], loss:0.1481
# TRAIN: epoch[1/5], loss:0.1618
# TRAIN: epoch[1/5], loss:0.1649
# TRAIN: epoch[1/5], loss:0.1548
# TRAIN: epoch[1/5], loss:0.1491
# TRAIN: epoch[1/5], loss:0.1443
# TRAIN: epoch[1/5], loss:0.1208
# TRAIN: epoch[1/5], loss:0.1442
# TRAIN: epoch[1/5], loss:0.1397
# TRAIN: epoch[1/5], loss:0.1420
# TRAIN: epoch[1/5], loss:0.1457
# TRAIN: epoch[1/5], loss:0.1387
# TRAIN: epoch[1/5], loss:0.1997
# TRAIN: epoch[1/5], loss:0.1833
# TRAIN: epoch[1/5], loss:0.1683
# TRAIN: epoch[1/5], loss:0.1676
# TRAIN: epoch[1/5], loss:0.1391
# TRAIN: epoch[1/5], loss:0.1508
# TRAIN: epoch[1/5], loss:0.1577
# TRAIN: epoch[1/5], loss:0.1360
# TRAIN: epoch[1/5], loss:0.1244
# TRAIN: epoch[1/5], loss:0.1252
# TRAIN: epoch[1/5], loss:0.1262
# TRAIN: epoch[1/5], loss:0.1636
# TRAIN: epoch[1/5], loss:0.1532
# TRAIN: epoch[1/5], loss:0.1445
# TRAIN: epoch[1/5], loss:0.1489
# TRAIN: epoch[1/5], loss:0.1363
# TRAIN: epoch[1/5], loss:0.1353
# TRAIN: epoch[1/5], loss:0.1378
# TRAIN: epoch[1/5], loss:0.1325
# TRAIN: epoch[1/5], loss:0.1287
# TRAIN: epoch[1/5], loss:0.1263
# TRAIN: epoch[1/5], loss:0.1515
# TRAIN: epoch[1/5], loss:0.1526
# TRAIN: epoch[1/5], loss:0.1598
# TRAIN: epoch[1/5], loss:0.1553
# TRAIN: epoch[1/5], loss:0.1444
# TRAIN: epoch[1/5], loss:0.1339
# TRAIN: epoch[1/5], loss:0.1419
# TRAIN: epoch[1/5], loss:0.1711
# TRAIN: epoch[1/5], loss:0.1670
# TRAIN: epoch[1/5], loss:0.1590
# TRAIN: epoch[1/5], loss:0.1615
# TRAIN: epoch[1/5], loss:0.1494
# TRAIN: epoch[1/5], loss:0.1583
# TRAIN: epoch[1/5], loss:0.1372
# TRAIN: epoch[1/5], loss:0.1359
# TRAIN: epoch[1/5], loss:0.1446
# TRAIN: epoch[1/5], loss:0.1316
# TRAIN: epoch[1/5], loss:0.1356
# TRAIN: epoch[1/5], loss:0.1281
# TRAIN: epoch[1/5], loss:0.1429
# TRAIN: epoch[1/5], loss:0.1680
# TRAIN: epoch[1/5], loss:0.1600
# TRAIN: epoch[1/5], loss:0.1624
# TRAIN: epoch[1/5], loss:0.1641
# TRAIN: epoch[1/5], loss:0.1721
# TRAIN: epoch[1/5], loss:0.1671
# TRAIN: epoch[1/5], loss:0.1609
# TRAIN: epoch[1/5], loss:0.1769
# TRAIN: epoch[1/5], loss:0.1729
# TRAIN: epoch[1/5], loss:0.1639
# TRAIN: epoch[1/5], loss:0.1643
# TRAIN: epoch[1/5], loss:0.1549
# TRAIN: epoch[1/5], loss:0.1473
# TRAIN: epoch[1/5], loss:0.1519
# TRAIN: epoch[1/5], loss:0.1474
# TRAIN: epoch[1/5], loss:0.1674
# TRAIN: epoch[1/5], loss:0.1589
# TRAIN: epoch[1/5], loss:0.1584
# TRAIN: epoch[1/5], loss:0.1292
# TRAIN: epoch[1/5], loss:0.1347
# TRAIN: epoch[1/5], loss:0.1399
# TRAIN: epoch[1/5], loss:0.1770
# TRAIN: epoch[1/5], loss:0.1732
# TRAIN: epoch[1/5], loss:0.1761
# TRAIN: epoch[1/5], loss:0.1684
# TRAIN: epoch[1/5], loss:0.1378
# TRAIN: epoch[1/5], loss:0.1320
# TRAIN: epoch[1/5], loss:0.1414
# TRAIN: epoch[1/5], loss:0.1298
# TRAIN: epoch[1/5], loss:0.1278
# TRAIN: epoch[1/5], loss:0.1295
# TRAIN: epoch[1/5], loss:0.1304
# TRAIN: epoch[1/5], loss:0.1185
# TRAIN: epoch[1/5], loss:0.1467
# TRAIN: epoch[1/5], loss:0.1431
# TRAIN: epoch[1/5], loss:0.1413
# TRAIN: epoch[1/5], loss:0.1395
# TRAIN: epoch[1/5], loss:0.1380
# TRAIN: epoch[1/5], loss:0.1525
# TRAIN: epoch[1/5], loss:0.1582
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1434
# TRAIN: epoch[1/5], loss:0.1100
# TRAIN: epoch[1/5], loss:0.1185
# TRAIN: epoch[1/5], loss:0.1210
# TRAIN: epoch[1/5], loss:0.1507
# TRAIN: epoch[1/5], loss:0.1460
# TRAIN: epoch[1/5], loss:0.1339
# TRAIN: epoch[1/5], loss:0.1370
# TRAIN: epoch[1/5], loss:0.1401
# TRAIN: epoch[1/5], loss:0.1354
# TRAIN: epoch[1/5], loss:0.1363
# TRAIN: epoch[1/5], loss:0.1384
# TRAIN: epoch[1/5], loss:0.1365
# TRAIN: epoch[1/5], loss:0.1315
# TRAIN: epoch[1/5], loss:0.1371
# TRAIN: epoch[1/5], loss:0.1251
# TRAIN: epoch[1/5], loss:0.1268
# TRAIN: epoch[1/5], loss:0.1292
# TRAIN: epoch[1/5], loss:0.1346
# TRAIN: epoch[1/5], loss:0.1403
# TRAIN: epoch[1/5], loss:0.1403
# TRAIN: epoch[1/5], loss:0.1359
# TRAIN: epoch[1/5], loss:0.1499
# TRAIN: epoch[1/5], loss:0.1582
# TRAIN: epoch[1/5], loss:0.1571
# TRAIN: epoch[1/5], loss:0.1491
# TRAIN: epoch[1/5], loss:0.1429
# TRAIN: epoch[1/5], loss:0.1622
# TRAIN: epoch[1/5], loss:0.1624
# TRAIN: epoch[1/5], loss:0.1765
# TRAIN: epoch[1/5], loss:0.1632
# TRAIN: epoch[1/5], loss:0.1400
# TRAIN: epoch[1/5], loss:0.1417
# TRAIN: epoch[1/5], loss:0.1352
# TRAIN: epoch[1/5], loss:0.1250
# TRAIN: epoch[1/5], loss:0.1380
# TRAIN: epoch[1/5], loss:0.1378
# TRAIN: epoch[1/5], loss:0.1510
# TRAIN: epoch[1/5], loss:0.1604
# TRAIN: epoch[1/5], loss:0.1644
# TRAIN: epoch[1/5], loss:0.1482
# TRAIN: epoch[1/5], loss:0.1533
# TRAIN: epoch[1/5], loss:0.1506
# TRAIN: epoch[1/5], loss:0.1512
# TRAIN: epoch[1/5], loss:0.1372
# TRAIN: epoch[1/5], loss:0.1300
# TRAIN: epoch[1/5], loss:0.1350
# TRAIN: epoch[1/5], loss:0.1226
# TRAIN: epoch[1/5], loss:0.1233
# TRAIN: epoch[1/5], loss:0.1368
# TRAIN: epoch[1/5], loss:0.1546
# TRAIN: epoch[1/5], loss:0.1673
# TRAIN: epoch[1/5], loss:0.1518
# TRAIN: epoch[1/5], loss:0.1462
# TRAIN: epoch[1/5], loss:0.1222
# TRAIN: epoch[1/5], loss:0.1427
# TRAIN: epoch[1/5], loss:0.1479
# TRAIN: epoch[1/5], loss:0.1376
# TRAIN: epoch[1/5], loss:0.1331
# TRAIN: epoch[1/5], loss:0.1506
# TRAIN: epoch[1/5], loss:0.1588
# TRAIN: epoch[1/5], loss:0.1508
# TRAIN: epoch[1/5], loss:0.1513
# TRAIN: epoch[1/5], loss:0.1518
# TRAIN: epoch[1/5], loss:0.1479
# TRAIN: epoch[1/5], loss:0.1510
# TRAIN: epoch[1/5], loss:0.1510
# TRAIN: epoch[1/5], loss:0.1505
# TRAIN: epoch[1/5], loss:0.1480
# TRAIN: epoch[1/5], loss:0.1466
# TRAIN: epoch[1/5], loss:0.1621
# TRAIN: epoch[1/5], loss:0.1447
# TRAIN: epoch[1/5], loss:0.1320
# TRAIN: epoch[1/5], loss:0.1323
# TRAIN: epoch[1/5], loss:0.1338
# TRAIN: epoch[1/5], loss:0.1512
# TRAIN: epoch[1/5], loss:0.1549
# TRAIN: epoch[1/5], loss:0.1593
# TRAIN: epoch[1/5], loss:0.1379
# TRAIN: epoch[1/5], loss:0.1349
# TRAIN: epoch[1/5], loss:0.1495
# TRAIN: epoch[1/5], loss:0.1405
# TRAIN: epoch[1/5], loss:0.1435
# TRAIN: epoch[1/5], loss:0.1314
# TRAIN: epoch[1/5], loss:0.1249
# TRAIN: epoch[1/5], loss:0.1208
# TRAIN: epoch[1/5], loss:0.1116
# TRAIN: epoch[1/5], loss:0.1552
# TRAIN: epoch[1/5], loss:0.1898
# TRAIN: epoch[1/5], loss:0.1698
# TRAIN: epoch[1/5], loss:0.1733
# TRAIN: epoch[1/5], loss:0.1378
# TRAIN: epoch[1/5], loss:0.1443
# TRAIN: epoch[1/5], loss:0.1372
# TRAIN: epoch[1/5], loss:0.1869
# TRAIN: epoch[1/5], loss:0.1754
# TRAIN: epoch[1/5], loss:0.1882
# TRAIN: epoch[1/5], loss:0.1816
# TRAIN: epoch[1/5], loss:0.1548
# TRAIN: epoch[1/5], loss:0.1555
# TRAIN: epoch[1/5], loss:0.1424
# TRAIN: epoch[1/5], loss:0.1362
# TRAIN: epoch[1/5], loss:0.1771
# TRAIN: epoch[1/5], loss:0.1700
# TRAIN: epoch[1/5], loss:0.1725
# TRAIN: epoch[1/5], loss:0.1739
# TRAIN: epoch[1/5], loss:0.1519
# TRAIN: epoch[1/5], loss:0.1500
# TRAIN: epoch[1/5], loss:0.1409
# TRAIN: epoch[1/5], loss:0.1326
# TRAIN: epoch[1/5], loss:0.1330
# TRAIN: epoch[1/5], loss:0.1281
# TRAIN: epoch[1/5], loss:0.1588
# TRAIN: epoch[1/5], loss:0.1602
# TRAIN: epoch[1/5], loss:0.1517
# TRAIN: epoch[1/5], loss:0.1417
# TRAIN: epoch[1/5], loss:0.1386
# TRAIN: epoch[1/5], loss:0.1254
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1559
# TRAIN: epoch[1/5], loss:0.1472
# TRAIN: epoch[1/5], loss:0.1435
# TRAIN: epoch[1/5], loss:0.1348
# TRAIN: epoch[1/5], loss:0.1363
# TRAIN: epoch[1/5], loss:0.1299
# TRAIN: epoch[1/5], loss:0.1444
# TRAIN: epoch[1/5], loss:0.1664
# TRAIN: epoch[1/5], loss:0.1415
# TRAIN: epoch[1/5], loss:0.1435
# TRAIN: epoch[1/5], loss:0.1463
# TRAIN: epoch[1/5], loss:0.1512
# TRAIN: epoch[1/5], loss:0.1381
# TRAIN: epoch[1/5], loss:0.1311
# TRAIN: epoch[1/5], loss:0.1511
# TRAIN: epoch[1/5], loss:0.1651
# TRAIN: epoch[1/5], loss:0.1619
# TRAIN: epoch[1/5], loss:0.1583
# TRAIN: epoch[1/5], loss:0.1556
# TRAIN: epoch[1/5], loss:0.1569
# TRAIN: epoch[1/5], loss:0.1638
# TRAIN: epoch[1/5], loss:0.1497
# TRAIN: epoch[1/5], loss:0.1566
# TRAIN: epoch[1/5], loss:0.1575
# TRAIN: epoch[1/5], loss:0.1377
# TRAIN: epoch[1/5], loss:0.1123
# TRAIN: epoch[1/5], loss:0.1344
# TRAIN: epoch[1/5], loss:0.1264
# TRAIN: epoch[1/5], loss:0.1493
# TRAIN: epoch[1/5], loss:0.1446
# TRAIN: epoch[1/5], loss:0.1494
# TRAIN: epoch[1/5], loss:0.1514
# TRAIN: epoch[1/5], loss:0.1431
# TRAIN: epoch[1/5], loss:0.1320
# TRAIN: epoch[1/5], loss:0.1315
# TRAIN: epoch[1/5], loss:0.1620
# TRAIN: epoch[1/5], loss:0.1684
# TRAIN: epoch[1/5], loss:0.1631
# TRAIN: epoch[1/5], loss:0.1507
# TRAIN: epoch[1/5], loss:0.1344
# TRAIN: epoch[1/5], loss:0.1361
# TRAIN: epoch[1/5], loss:0.1265
# TRAIN: epoch[1/5], loss:0.1428
# TRAIN: epoch[1/5], loss:0.1317
# TRAIN: epoch[1/5], loss:0.1353
# TRAIN: epoch[1/5], loss:0.1358
# TRAIN: epoch[1/5], loss:0.1370
# TRAIN: epoch[1/5], loss:0.1479
# TRAIN: epoch[1/5], loss:0.1346
# TRAIN: epoch[1/5], loss:0.1512
# TRAIN: epoch[1/5], loss:0.1511
# TRAIN: epoch[1/5], loss:0.1455
# TRAIN: epoch[1/5], loss:0.1296
# TRAIN: epoch[1/5], loss:0.1507
# TRAIN: epoch[1/5], loss:0.1389
# TRAIN: epoch[1/5], loss:0.1133
# TRAIN: epoch[1/5], loss:0.1082
# TRAIN: epoch[1/5], loss:0.1256
# TRAIN: epoch[1/5], loss:0.1530
# TRAIN: epoch[1/5], loss:0.1548
# TRAIN: epoch[1/5], loss:0.1622
# TRAIN: epoch[1/5], loss:0.1598
# TRAIN: epoch[1/5], loss:0.1542
# TRAIN: epoch[1/5], loss:0.1522
# TRAIN: epoch[1/5], loss:0.1540
# TRAIN: epoch[1/5], loss:0.1424
# TRAIN: epoch[1/5], loss:0.1455
# TRAIN: epoch[1/5], loss:0.1327
# TRAIN: epoch[1/5], loss:0.1302
# TRAIN: epoch[1/5], loss:0.1679
# TRAIN: epoch[1/5], loss:0.1739
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1607
# TRAIN: epoch[1/5], loss:0.1526
# TRAIN: epoch[1/5], loss:0.1401
# TRAIN: epoch[1/5], loss:0.1241
# TRAIN: epoch[1/5], loss:0.1315
# TRAIN: epoch[1/5], loss:0.1269
# TRAIN: epoch[1/5], loss:0.1554
# TRAIN: epoch[1/5], loss:0.1509
# TRAIN: epoch[1/5], loss:0.1434
# TRAIN: epoch[1/5], loss:0.1439
# TRAIN: epoch[1/5], loss:0.1461
# TRAIN: epoch[1/5], loss:0.1487
# TRAIN: epoch[1/5], loss:0.1359
# TRAIN: epoch[1/5], loss:0.1499
# TRAIN: epoch[1/5], loss:0.1461
# TRAIN: epoch[1/5], loss:0.1449
# TRAIN: epoch[1/5], loss:0.1364
# TRAIN: epoch[1/5], loss:0.1335
# TRAIN: epoch[1/5], loss:0.1272
# TRAIN: epoch[1/5], loss:0.1235
# TRAIN: epoch[1/5], loss:0.1427
# TRAIN: epoch[1/5], loss:0.1303
# TRAIN: epoch[1/5], loss:0.1370
# TRAIN: epoch[1/5], loss:0.1444
# TRAIN: epoch[1/5], loss:0.1457
# TRAIN: epoch[1/5], loss:0.1320
# TRAIN: epoch[1/5], loss:0.1475
# TRAIN: epoch[1/5], loss:0.1370
# TRAIN: epoch[1/5], loss:0.1381
# TRAIN: epoch[1/5], loss:0.1372
# TRAIN: epoch[1/5], loss:0.1339
# TRAIN: epoch[1/5], loss:0.1353
# TRAIN: epoch[1/5], loss:0.1293
# TRAIN: epoch[1/5], loss:0.1413
# TRAIN: epoch[1/5], loss:0.1501
# TRAIN: epoch[1/5], loss:0.1447
# TRAIN: epoch[1/5], loss:0.1496
# TRAIN: epoch[1/5], loss:0.1442
# TRAIN: epoch[1/5], loss:0.1419
# TRAIN: epoch[1/5], loss:0.1443
# TRAIN: epoch[1/5], loss:0.1366
# TRAIN: epoch[1/5], loss:0.1342
# TRAIN: epoch[1/5], loss:0.1238
# TRAIN: epoch[1/5], loss:0.1416
# TRAIN: epoch[1/5], loss:0.1359
# TRAIN: epoch[1/5], loss:0.1380
# TRAIN: epoch[1/5], loss:0.1412
# TRAIN: epoch[1/5], loss:0.1391
# TRAIN: epoch[1/5], loss:0.1412
# TRAIN: epoch[1/5], loss:0.1253
# TRAIN: epoch[1/5], loss:0.1130
# TRAIN: epoch[1/5], loss:0.1225
# TRAIN: epoch[1/5], loss:0.1226
# TRAIN: epoch[1/5], loss:0.1302
# TRAIN: epoch[1/5], loss:0.1358
# TRAIN: epoch[1/5], loss:0.1325
# TRAIN: epoch[1/5], loss:0.1492
# TRAIN: epoch[1/5], loss:0.1408
# TRAIN: epoch[1/5], loss:0.1398
# TRAIN: epoch[1/5], loss:0.1413
# TRAIN: epoch[1/5], loss:0.1440
# TRAIN: epoch[1/5], loss:0.1606
# TRAIN: epoch[1/5], loss:0.1488
# TRAIN: epoch[1/5], loss:0.1545
# TRAIN: epoch[1/5], loss:0.1513
# TRAIN: epoch[1/5], loss:0.1472
# TRAIN: epoch[1/5], loss:0.1443
# TRAIN: epoch[1/5], loss:0.1441
# TRAIN: epoch[1/5], loss:0.1467
# TRAIN: epoch[1/5], loss:0.1263
# TRAIN: epoch[1/5], loss:0.1248
# TRAIN: epoch[1/5], loss:0.1203
# TRAIN: epoch[1/5], loss:0.1533
# TRAIN: epoch[1/5], loss:0.1496
# TRAIN: epoch[1/5], loss:0.1464
# TRAIN: epoch[1/5], loss:0.1709
# TRAIN: epoch[1/5], loss:0.1754
# TRAIN: epoch[1/5], loss:0.1607
# TRAIN: epoch[1/5], loss:0.1531
# TRAIN: epoch[1/5], loss:0.1547
# TRAIN: epoch[1/5], loss:0.1538
# TRAIN: epoch[1/5], loss:0.1407
# TRAIN: epoch[1/5], loss:0.1715
# TRAIN: epoch[1/5], loss:0.1532
# TRAIN: epoch[1/5], loss:0.1696
# TRAIN: epoch[1/5], loss:0.1665
# TRAIN: epoch[1/5], loss:0.1655
# TRAIN: epoch[1/5], loss:0.1621
# TRAIN: epoch[1/5], loss:0.1601
# TRAIN: epoch[1/5], loss:0.1533
# TRAIN: epoch[1/5], loss:0.1607
# TRAIN: epoch[1/5], loss:0.1479
# TRAIN: epoch[1/5], loss:0.1539
# TRAIN: epoch[1/5], loss:0.1577
# TRAIN: epoch[1/5], loss:0.1557
# TRAIN: epoch[1/5], loss:0.1489
# TRAIN: epoch[1/5], loss:0.1183
# TRAIN: epoch[1/5], loss:0.1219
# TRAIN: epoch[1/5], loss:0.1323
# TRAIN: epoch[1/5], loss:0.1494
# TRAIN: epoch[1/5], loss:0.1533
# TRAIN: epoch[1/5], loss:0.1463
# TRAIN: epoch[1/5], loss:0.1382
# TRAIN: epoch[1/5], loss:0.1395
# TRAIN: epoch[1/5], loss:0.1472
# TRAIN: epoch[1/5], loss:0.1447
# TRAIN: epoch[1/5], loss:0.1407
# TRAIN: epoch[1/5], loss:0.1405
# TRAIN: epoch[1/5], loss:0.1258
# TRAIN: epoch[1/5], loss:0.1538
# TRAIN: epoch[1/5], loss:0.1349
# TRAIN: epoch[1/5], loss:0.1317
# TRAIN: epoch[1/5], loss:0.1221
# TRAIN: epoch[1/5], loss:0.1312
# TRAIN: epoch[1/5], loss:0.1369
# TRAIN: epoch[1/5], loss:0.1431
# TRAIN: epoch[1/5], loss:0.1330
# TRAIN: epoch[1/5], loss:0.1336
# TRAIN: epoch[1/5], loss:0.1405
# TRAIN: epoch[1/5], loss:0.1337
# TRAIN: epoch[1/5], loss:0.1365
# TRAIN: epoch[1/5], loss:0.1449
# TRAIN: epoch[1/5], loss:0.1340
# TRAIN: epoch[1/5], loss:0.1317
# TRAIN: epoch[1/5], loss:0.1418
# TRAIN: epoch[1/5], loss:0.1557
# TRAIN: epoch[1/5], loss:0.1447
# TRAIN: epoch[1/5], loss:0.1486
# TRAIN: epoch[1/5], loss:0.1355
# TRAIN: epoch[1/5], loss:0.1344
# TRAIN: epoch[1/5], loss:0.1476
# TRAIN: epoch[1/5], loss:0.1606
# TRAIN: epoch[1/5], loss:0.1679
# TRAIN: epoch[1/5], loss:0.1573
# TRAIN: epoch[1/5], loss:0.1513
# TRAIN: epoch[1/5], loss:0.1440
# TRAIN: epoch[1/5], loss:0.1549
# TRAIN: epoch[1/5], loss:0.1351
# TRAIN: epoch[1/5], loss:0.1494
# TRAIN: epoch[1/5], loss:0.1323
# TRAIN: epoch[1/5], loss:0.1298
# TRAIN: epoch[1/5], loss:0.1358
# TRAIN: epoch[1/5], loss:0.1264
# TRAIN: epoch[1/5], loss:0.1411
# TRAIN: epoch[1/5], loss:0.1315
# TRAIN: epoch[1/5], loss:0.1162
# TRAIN: epoch[1/5], loss:0.1329
# TRAIN: epoch[1/5], loss:0.1244
# TRAIN: epoch[1/5], loss:0.1201
# TRAIN: epoch[1/5], loss:0.1355
# TRAIN: epoch[1/5], loss:0.1298
# TRAIN: epoch[1/5], loss:0.1653
# TRAIN: epoch[1/5], loss:0.1443
# TRAIN: epoch[1/5], loss:0.1427
# TRAIN: epoch[1/5], loss:0.1344
# TRAIN: epoch[1/5], loss:0.1293
# TRAIN: epoch[1/5], loss:0.1232
# TRAIN: epoch[1/5], loss:0.1393
# TRAIN: epoch[1/5], loss:0.1445
# TRAIN: epoch[1/5], loss:0.1501
# TRAIN: epoch[1/5], loss:0.1560
# TRAIN: epoch[1/5], loss:0.1554
# TRAIN: epoch[1/5], loss:0.1355
# TRAIN: epoch[1/5], loss:0.1470
# TRAIN: epoch[1/5], loss:0.1387
# TRAIN: epoch[1/5], loss:0.1310
# TRAIN: epoch[1/5], loss:0.1386
# TRAIN: epoch[1/5], loss:0.1321
# TRAIN: epoch[1/5], loss:0.1341
# TRAIN: epoch[1/5], loss:0.1224
# TRAIN: epoch[1/5], loss:0.1347
# TRAIN: epoch[1/5], loss:0.1300
# TRAIN: epoch[1/5], loss:0.1172
# TRAIN: epoch[1/5], loss:0.1316
# TRAIN: epoch[1/5], loss:0.1460
# TRAIN: epoch[1/5], loss:0.1464
# TRAIN: epoch[1/5], loss:0.1401
# TRAIN: epoch[1/5], loss:0.1428
# TRAIN: epoch[1/5], loss:0.1349
# TRAIN: epoch[1/5], loss:0.1212
# TRAIN: epoch[1/5], loss:0.1215
# TRAIN: epoch[1/5], loss:0.1532
# TRAIN: epoch[1/5], loss:0.1453
# TRAIN: epoch[1/5], loss:0.1567
# TRAIN: epoch[1/5], loss:0.1523
# TRAIN: epoch[1/5], loss:0.1512
# TRAIN: epoch[1/5], loss:0.1512
# TRAIN: epoch[1/5], loss:0.1495
# TRAIN: epoch[1/5], loss:0.1519
# TRAIN: epoch[1/5], loss:0.1311
# TRAIN: epoch[1/5], loss:0.1424
# TRAIN: epoch[1/5], loss:0.1500
# TRAIN: epoch[1/5], loss:0.1397
# TRAIN: epoch[1/5], loss:0.1464
# TRAIN: epoch[1/5], loss:0.1429
# TRAIN: epoch[1/5], loss:0.1463
# TRAIN: epoch[1/5], loss:0.1337
# TRAIN: epoch[1/5], loss:0.1344
# TRAIN: epoch[1/5], loss:0.1373
# TRAIN: epoch[1/5], loss:0.1616
# TRAIN: epoch[1/5], loss:0.1526
# TRAIN: epoch[1/5], loss:0.1784
# TRAIN: epoch[1/5], loss:0.1688
# TRAIN: epoch[1/5], loss:0.1675
# TRAIN: epoch[1/5], loss:0.1442
# TRAIN: epoch[1/5], loss:0.1413
# TRAIN: epoch[1/5], loss:0.1438
# TRAIN: epoch[1/5], loss:0.1423
# TRAIN: epoch[1/5], loss:0.1396
# TRAIN: epoch[1/5], loss:0.1465
# TRAIN: epoch[1/5], loss:0.1467
# TRAIN: epoch[1/5], loss:0.1293
# TRAIN: epoch[1/5], loss:0.1269
# TRAIN: epoch[1/5], loss:0.1236
# TRAIN: epoch[1/5], loss:0.1359
# TRAIN: epoch[1/5], loss:0.1404
# TRAIN: epoch[1/5], loss:0.1348
# TRAIN: epoch[1/5], loss:0.1366
# TRAIN: epoch[1/5], loss:0.1625
# TRAIN: epoch[1/5], loss:0.1515
# TRAIN: epoch[1/5], loss:0.1504
# TRAIN: epoch[1/5], loss:0.1355
# TRAIN: epoch[1/5], loss:0.1280
# TRAIN: epoch[1/5], loss:0.1091
# TRAIN: epoch[1/5], loss:0.1234
# TRAIN: epoch[1/5], loss:0.1350
# TRAIN: epoch[1/5], loss:0.1426
# TRAIN: epoch[1/5], loss:0.1391
# TRAIN: epoch[1/5], loss:0.1392
# TRAIN: epoch[1/5], loss:0.1359
# TRAIN: epoch[1/5], loss:0.1468
# TRAIN: epoch[1/5], loss:0.1437
# TRAIN: epoch[1/5], loss:0.1328
# TRAIN: epoch[1/5], loss:0.1220
# TRAIN: epoch[1/5], loss:0.1216
# TRAIN: epoch[1/5], loss:0.1187
# TRAIN: epoch[1/5], loss:0.1298
# TRAIN: epoch[1/5], loss:0.1272
# TRAIN: epoch[1/5], loss:0.1427
# TRAIN: epoch[1/5], loss:0.1185
# TRAIN: epoch[1/5], loss:0.1170
# TRAIN: epoch[1/5], loss:0.1406
# TRAIN: epoch[1/5], loss:0.1483
# TRAIN: epoch[1/5], loss:0.1458
# TRAIN: epoch[1/5], loss:0.1591
# TRAIN: epoch[1/5], loss:0.1580
# TRAIN: epoch[1/5], loss:0.1251
# TRAIN: epoch[1/5], loss:0.1117
# TRAIN: epoch[1/5], loss:0.1072
# TRAIN: epoch[1/5], loss:0.1035
# TRAIN: epoch[1/5], loss:0.1181
# TRAIN: epoch[1/5], loss:0.1549
# TRAIN: epoch[1/5], loss:0.1430
# TRAIN: epoch[1/5], loss:0.1423
# TRAIN: epoch[1/5], loss:0.1332
# TRAIN: epoch[1/5], loss:0.1296
# TRAIN: epoch[1/5], loss:0.1388
# TRAIN: epoch[1/5], loss:0.1448
# TRAIN: epoch[1/5], loss:0.1598
# TRAIN: epoch[1/5], loss:0.2150
# TRAIN: epoch[1/5], loss:0.2542
# TRAIN: epoch[1/5], loss:0.1693
# TRAIN: epoch[1/5], loss:0.1221
# TRAIN: epoch[1/5], loss:0.1384
# TRAIN: epoch[1/5], loss:0.1537
# TRAIN: epoch[1/5], loss:0.1424
# TRAIN: epoch[1/5], loss:0.1571
# TRAIN: epoch[1/5], loss:0.1634
# TRAIN: epoch[1/5], loss:0.1194
# TRAIN: epoch[1/5], loss:0.1231
# TEST: epoch[1/5], loss:0.1386
# TEST: epoch[1/5], loss:0.1405
# TEST: epoch[1/5], loss:0.1350
# TEST: epoch[1/5], loss:0.1458
# TEST: epoch[1/5], loss:0.1319
# TEST: epoch[1/5], loss:0.1363
# TEST: epoch[1/5], loss:0.1328
# TEST: epoch[1/5], loss:0.1332
# TEST: epoch[1/5], loss:0.1386
# TEST: epoch[1/5], loss:0.1303
# TEST: epoch[1/5], loss:0.1412
# TEST: epoch[1/5], loss:0.1547
# TEST: epoch[1/5], loss:0.1466
# TEST: epoch[1/5], loss:0.1489
# TEST: epoch[1/5], loss:0.1426
# TEST: epoch[1/5], loss:0.1330
# TEST: epoch[1/5], loss:0.1217
# TEST: epoch[1/5], loss:0.1262
# TEST: epoch[1/5], loss:0.1531
# TEST: epoch[1/5], loss:0.1799
# TEST: epoch[1/5], loss:0.1685
# TEST: epoch[1/5], loss:0.1871
# TEST: epoch[1/5], loss:0.1391
# TEST: epoch[1/5], loss:0.1358
# TEST: epoch[1/5], loss:0.1352
# TEST: epoch[1/5], loss:0.1295
# TEST: epoch[1/5], loss:0.1310
# TEST: epoch[1/5], loss:0.1318
# TEST: epoch[1/5], loss:0.1321
# TEST: epoch[1/5], loss:0.1466
# TEST: epoch[1/5], loss:0.1598
# TEST: epoch[1/5], loss:0.1661
# TEST: epoch[1/5], loss:0.1508
# TEST: epoch[1/5], loss:0.1435
# TEST: epoch[1/5], loss:0.1380
# TEST: epoch[1/5], loss:0.1509
# TEST: epoch[1/5], loss:0.1388
# TEST: epoch[1/5], loss:0.1368
# TEST: epoch[1/5], loss:0.1385
# TEST: epoch[1/5], loss:0.1489
# TEST: epoch[1/5], loss:0.1436
# TEST: epoch[1/5], loss:0.1513
# TEST: epoch[1/5], loss:0.1367
# TEST: epoch[1/5], loss:0.1446
# TEST: epoch[1/5], loss:0.1537
# TEST: epoch[1/5], loss:0.1433
# TEST: epoch[1/5], loss:0.1228
# TEST: epoch[1/5], loss:0.1375
# TEST: epoch[1/5], loss:0.1253
# TEST: epoch[1/5], loss:0.1266
# TEST: epoch[1/5], loss:0.1290
# TEST: epoch[1/5], loss:0.1263
# TEST: epoch[1/5], loss:0.1420
# TEST: epoch[1/5], loss:0.1403
# TEST: epoch[1/5], loss:0.1301
# TEST: epoch[1/5], loss:0.1398
# TEST: epoch[1/5], loss:0.1376
# TEST: epoch[1/5], loss:0.1354
# TEST: epoch[1/5], loss:0.1469
# TEST: epoch[1/5], loss:0.1525
# TEST: epoch[1/5], loss:0.1753
# TEST: epoch[1/5], loss:0.1686
# TEST: epoch[1/5], loss:0.1516
# TEST: epoch[1/5], loss:0.1595
# TEST: epoch[1/5], loss:0.1629
# TEST: epoch[1/5], loss:0.1567
# TEST: epoch[1/5], loss:0.1712
# TEST: epoch[1/5], loss:0.1535
# TEST: epoch[1/5], loss:0.1438
# TEST: epoch[1/5], loss:0.1475
# TEST: epoch[1/5], loss:0.1504
# TEST: epoch[1/5], loss:0.1485
# TEST: epoch[1/5], loss:0.1406
# TEST: epoch[1/5], loss:0.1346
# TEST: epoch[1/5], loss:0.1301
# TEST: epoch[1/5], loss:0.1199
# TEST: epoch[1/5], loss:0.1228
# TEST: epoch[1/5], loss:0.1454
# TEST: epoch[1/5], loss:0.1441
# TEST: epoch[1/5], loss:0.1356
# TEST: epoch[1/5], loss:0.1412
# TEST: epoch[1/5], loss:0.1472
# TEST: epoch[1/5], loss:0.1452
# TEST: epoch[1/5], loss:0.1369
# TEST: epoch[1/5], loss:0.1385
# TEST: epoch[1/5], loss:0.1393
# TEST: epoch[1/5], loss:0.1255
# TEST: epoch[1/5], loss:0.1551
# TEST: epoch[1/5], loss:0.1477
# TEST: epoch[1/5], loss:0.1358
# TEST: epoch[1/5], loss:0.1486
# TEST: epoch[1/5], loss:0.1563
# TEST: epoch[1/5], loss:0.1451
# TEST: epoch[1/5], loss:0.1407
# TEST: epoch[1/5], loss:0.1348
# TEST: epoch[1/5], loss:0.1110
# TEST: epoch[1/5], loss:0.1338
# TEST: epoch[1/5], loss:0.1305
# TEST: epoch[1/5], loss:0.1301
# TEST: epoch[1/5], loss:0.1337
# TEST: epoch[1/5], loss:0.1288
# TEST: epoch[1/5], loss:0.1886
# TEST: epoch[1/5], loss:0.1738
# TEST: epoch[1/5], loss:0.1600
# TEST: epoch[1/5], loss:0.1597
# TEST: epoch[1/5], loss:0.1286
# TEST: epoch[1/5], loss:0.1406
# TEST: epoch[1/5], loss:0.1470
# TEST: epoch[1/5], loss:0.1273
# TEST: epoch[1/5], loss:0.1140
# TEST: epoch[1/5], loss:0.1151
# TEST: epoch[1/5], loss:0.1149
# TEST: epoch[1/5], loss:0.1530
# TEST: epoch[1/5], loss:0.1443
# TEST: epoch[1/5], loss:0.1352
# TEST: epoch[1/5], loss:0.1411
# TEST: epoch[1/5], loss:0.1275
# TEST: epoch[1/5], loss:0.1261
# TEST: epoch[1/5], loss:0.1290
# TEST: epoch[1/5], loss:0.1227
# TEST: epoch[1/5], loss:0.1197
# TEST: epoch[1/5], loss:0.1154
# TEST: epoch[1/5], loss:0.1414
# TEST: epoch[1/5], loss:0.1432
# TEST: epoch[1/5], loss:0.1513
# TEST: epoch[1/5], loss:0.1471
# TEST: epoch[5/5], loss:0.1621
# TEST: epoch[5/5], loss:0.1143
# TEST: epoch[5/5], loss:0.1302
# TEST: epoch[5/5], loss:0.1455
# TEST: epoch[5/5], loss:0.1338
# TEST: epoch[5/5], loss:0.1497
# TEST: epoch[5/5], loss:0.1564
# TEST: epoch[5/5], loss:0.1100
# TEST: epoch[5/5], loss:0.1133

# %% [markdown]
# Saving the weights of the autoencoder:

# %%
pretrained_dict = model.state_dict()
torch.save(pretrained_dict, 'weights_autoencoder.pt')

# %% [markdown]
# **STEP 3** - Digit Classifier

# %%
class Classifier(nn.Module):

  def __init__(self):
    super(Classifier,self).__init__()

    self.encoder = nn.Sequential(
      nn.Conv2d(hparams['num_inputs'], hparams['hidden_size'], 4, padding=3, stride=2), # surten 16,16
      nn.ReLU(True),
      nn.Conv2d(hparams['hidden_size'], hparams['hidden_size_2'], 4, padding=1, stride=2), #surten 8,8
      nn.ReLU(True),
      nn.Conv2d(hparams['hidden_size_2'], 25, 4, stride=2), #surten 3,3
      nn.ReLU(True),
      nn.MaxPool2d(2, stride=1) # surten 2,2
    )

    self.fc = nn.Sequential(
        nn.Linear(100,10),     # El profe va comentar que Softmax podria ser una possibilitat també!!   
        nn.Softmax(dim=1)
    )
  
  def forward(self,x):
    x = self.encoder(x)
    x = x.view(-1)
    x = self.fc(x)
    return x

# %% [markdown]
# **STEP 4** - Pre-Training.

# %%
model = Classifier()
model_dict = model.state_dict()
pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict}
model_dict.update(pretrained_dict)
model.load_state_dict(model_dict)
model = model.to(hparams['device'])

# model = Classifier()
# model_dict = model.state_dict()
# pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict}
# model_dict.update(pretrained_dict)
# model = model.load_state_dict(torch.load('weights_autoencoder.pt'))
# model = model.to(hparams['device'])

distance = nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=hparams['learning_rate'], weight_decay=1e-5)

for epoch in range (hparams['num_epochs']):
  for batch_id, data in enumerate(samples_train):
    img, _ = data
    img = img.to(hparams['device'])
    # Forward pass
    output = model(img)
    loss = distance(output, img)
    losses_train.append(loss.cpu().data.item())
    # Backward pass
    optimizer.zero_grad() 
    loss.backward()
    optimizer.step()
    # Log message
    print('TRAIN: epoch[{}/{}], loss:{:.4f}'.format(epoch+1, hparams['num_epochs'], loss.item()))
  for data in samples_test:
    img, _ = data
    img = img.to(hparams['device'])
    # Forward pass
    output = model(img)
    loss = distance(output, img)
    losses_test.append(loss.cpu().data.item())
    # Backward pass
    optimizer.zero_grad() 
    loss.backward()
    optimizer.step()
    # Log message
    print('TEST: epoch[{}/{}], loss:{:.4f}'.format(epoch+1, hparams['num_epochs'], loss.item()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-9291a7d064f2> in <module>()
#      17
#      18 for epoch in range (hparams['num_epochs']):
# ---> 19   for batch_id, data in enumerate(samples_train):
#      20     img, _ = data
#      21     img = img.to(hparams['device'])
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     255
#     256     def __getitem__(self, idx):
# --> 257         return self.dataset[self.indices[idx]]
#     258
#     259     def __len__(self):
#
# TypeError: 'int' object is not subscriptable
